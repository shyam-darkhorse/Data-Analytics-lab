# %% [markdown]
# # Inbuilt PCA

# %%
import pandas as pd
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# load dataset into Pandas DataFrame
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])
df
# Out:
#      sepal length  sepal width  petal length  petal width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
from sklearn.preprocessing import StandardScaler
features = ['sepal length', 'sepal width', 'petal length', 'petal width']
# Separating out the features
x = df.loc[:, features].values
# Separating out the target
y = df.loc[:,['target']].values
# Standardizing the features
x = StandardScaler().fit_transform(x)
x
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf
# Out:
#      principal component 1  principal component 2
# 0                -2.264542               0.505704
# 1                -2.086426              -0.655405
# 2                -2.367950              -0.318477
# 3                -2.304197              -0.575368
# 4                -2.388777               0.674767
# 5                -2.070537               1.518549
# 6                -2.445711               0.074563
# 7                -2.233842               0.247614
# 8                -2.341958              -1.095146
# 9                -2.188676              -0.448629
# 10               -2.163487               1.070596
# 11               -2.327378               0.158587
# 12               -2.224083              -0.709118
# 13               -2.639716              -0.938282
# 14               -2.192292               1.889979
# 15               -2.251465               2.722371
# 16               -2.202750               1.513750
# 17               -2.190179               0.514304
# ...

# %%
finalDf = pd.concat([principalDf, df[['target']]], axis = 1)
finalDf
# Out:
#      principal component 1  principal component 2          target
# 0                -2.264542               0.505704     Iris-setosa
# 1                -2.086426              -0.655405     Iris-setosa
# 2                -2.367950              -0.318477     Iris-setosa
# 3                -2.304197              -0.575368     Iris-setosa
# 4                -2.388777               0.674767     Iris-setosa
# 5                -2.070537               1.518549     Iris-setosa
# 6                -2.445711               0.074563     Iris-setosa
# 7                -2.233842               0.247614     Iris-setosa
# 8                -2.341958              -1.095146     Iris-setosa
# 9                -2.188676              -0.448629     Iris-setosa
# 10               -2.163487               1.070596     Iris-setosa
# 11               -2.327378               0.158587     Iris-setosa
# 12               -2.224083              -0.709118     Iris-setosa
# ...

# %% [markdown]
# # using numpy

# %%
import matplotlib.pyplot as mp

features = ['sepal length', 'sepal width', 'petal length', 'petal width']
# Separating out the features
x = sepal_length = np.array(df['sepal length'])
y = sepal_width = np.array(df['sepal width'])
petal_length = np.array(df.loc[:, 'petal length'].values)
petal_width = np.array(df.loc[:, 'petal width'].values)
#y = np.array(df['target'])
mp.scatter(x,y,s=50)
mp.show()

# %%
mean_sl = np.mean(sepal_length)
mean_sw = np.mean(sepal_width)
mean_pl = np.mean(petal_length)
mean_pw = np.mean(petal_width)

sepal_length =  sepal_length - mean_sl
sepal_width = sepal_width - mean_sw
petal_length = petal_length - mean_pl 
petal_width = petal_width - mean_pw

mp.scatter(sepal_length,sepal_width,s =10)
mp.show()

# %%
X  = np.vstack((sepal_length,sepal_width,petal_length,petal_width)).T
X
# Out:
# array([[-7.43333333e-01,  4.46000000e-01, -2.35866667e+00,
#         -9.98666667e-01],
#        [-9.43333333e-01, -5.40000000e-02, -2.35866667e+00,
#         -9.98666667e-01],
#        [-1.14333333e+00,  1.46000000e-01, -2.45866667e+00,
#         -9.98666667e-01],
#        [-1.24333333e+00,  4.60000000e-02, -2.25866667e+00,
#         -9.98666667e-01],
#        [-8.43333333e-01,  5.46000000e-01, -2.35866667e+00,
#         -9.98666667e-01],
#        [-4.43333333e-01,  8.46000000e-01, -2.05866667e+00,
#         -7.98666667e-01],
#        [-1.24333333e+00,  3.46000000e-01, -2.35866667e+00,
#         -8.98666667e-01],
#        [-8.43333333e-01,  3.46000000e-01, -2.25866667e+00,
#         -9.98666667e-01],
#        [-1.44333333e+00, -1.54000000e-01, -2.35866667e+00,
#         -9.98666667e-01],
#        [-9.43333333e-01,  4.60000000e-02, -2.25866667e+00,
#         -1.09866667e+00],
#        [-4.43333333e-01,  6.46000000e-01, -2.25866667e+00,
#         -9.98666667e-01],
# ...

# %%
Xt = np.transpose(X)
cov = np.cov(Xt)
cov
# Out:
# array([[ 0.68569351, -0.03926846,  1.27368233,  0.5169038 ],
#        [-0.03926846,  0.18800403, -0.32171275, -0.11798121],
#        [ 1.27368233, -0.32171275,  3.11317942,  1.29638747],
#        [ 0.5169038 , -0.11798121,  1.29638747,  0.58241432]])

# %%
w,v = np.linalg.eig(cov)
print(w,"\n",v)
# Out:
# [4.22484077 0.24224357 0.07852391 0.02368303]
#  [[ 0.36158968 -0.65653988 -0.58099728  0.31725455]
#  [-0.08226889 -0.72971237  0.59641809 -0.32409435]
#  [ 0.85657211  0.1757674   0.07252408 -0.47971899]
#  [ 0.35884393  0.07470647  0.54906091  0.75112056]]

# %%
#taking 2 dim

pc1 = v[:,0]
pc2 = v[:,1]
print(pc1,'\n\n',pc2)
# Out:
# [ 0.36158968 -0.08226889  0.85657211  0.35884393]
#
#  [-0.65653988 -0.72971237  0.1757674   0.07470647]

# %%
E = np.vstack((pc1, pc2)).T
new_coord = X.dot(E)
new_coord
# Out:
# array([[-2.68420713, -0.32660731],
#        [-2.71539062,  0.16955685],
#        [-2.88981954,  0.13734561],
#        [-2.7464372 ,  0.31112432],
#        [-2.72859298, -0.33392456],
#        [-2.27989736, -0.74778271],
#        [-2.82089068,  0.08210451],
#        [-2.62648199, -0.17040535],
#        [-2.88795857,  0.57079803],
#        [-2.67384469,  0.1066917 ],
#        [-2.50652679, -0.65193501],
#        [-2.61314272, -0.02152063],
#        [-2.78743398,  0.22774019],
#        [-3.22520045,  0.50327991],
#        [-2.64354322, -1.1861949 ],
#        [-2.38386932, -1.34475434],
#        [-2.6225262 , -0.81808967],
#        [-2.64832273, -0.31913667],
#        [-2.19907796, -0.87924409],
#        [-2.58734619, -0.52047364],
#        [-2.3105317 , -0.39786782],
#        [-2.54323491, -0.44003175],
#        [-3.21585769, -0.14161557],
#        [-2.30312854, -0.10552268],
#        [-2.35617109,  0.03120959],
#        [-2.50791723,  0.13905634],
#        [-2.469056  , -0.13788731],
# ...
